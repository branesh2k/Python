# %%
import pandas as pd
from datasets import load_dataset

# Loading dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# data cleanup
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %% [markdown]
# ### Accessing data

# %%
df.iloc[:3]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
#
#    salary_year_avg  salary_hour_avg                company_name  \
# 0              NaN              NaN        Boehringer Ingelheim
# 1              NaN              NaN  Hewlett Packard Enterprise
# 2              NaN              NaN    ALPHA Augmented Services
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...

# %%
df.iloc[0:2,0:4]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via
# 0                 Watertown, CT   via Work Nearby
# 1  Guadalajara, Jalisco, Mexico  via BeBee México

# %%
df.loc[0:2,'job_title':'job_via']
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via
# 0                 Watertown, CT   via Work Nearby
# 1  Guadalajara, Jalisco, Mexico  via BeBee México
# 2               Berlin, Germany      via LinkedIn

# %%
df.loc[:,'salary_rate':'salary_hour_avg']
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 0             None              NaN              NaN
# 1             None              NaN              NaN
# 2             None              NaN              NaN
# 3             None              NaN              NaN
# 4             None              NaN              NaN
# ...            ...              ...              ...
# 785736        None              NaN              NaN
# 785737        None              NaN              NaN
# 785738        None              NaN              NaN
# 785739        None              NaN              NaN
# 785740        None              NaN              NaN
#
# [785741 rows x 3 columns]

# %% [markdown]
# ### Data: Cleaning

# %%
df.loc[:,'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df.loc[:10,'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %% [markdown]
# * `Cleaning` replacing the NaN values with median and removing the duplicate rows of job title.

# %%
median_salary_year = df['salary_year_avg'].median()
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_fillna = df

# %%
df_fillna['salary_year_avg'] = df_fillna['salary_year_avg'].fillna(median_salary_year)
df_fillna['salary_hour_avg'] = df_fillna['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_fillna.loc[:5,'salary_year_avg':'salary_hour_avg']
# Out:
#    salary_year_avg  salary_hour_avg
# 0         115000.0            45.98
# 1         115000.0            45.98
# 2         115000.0            45.98
# 3         115000.0            45.98
# 4         115000.0            45.98
# 5         115000.0            45.98

# %%
df_unique = df_fillna

# %%
df_unique=df_unique.drop_duplicates()

print('original no of rows df:', len(df_fillna))
print('no of unique rows df:', len(df_unique))
print('deleted rows = ', len(df_fillna)-len(df_unique))
# Out:
# original no of rows df: 785741
# no of unique rows df: 785640
# deleted rows =  101

# %%
df_unique = df_unique.drop_duplicates(subset=['job_title','company_name'])

print('original no of rows df:', len(df_fillna))
print('no of unique rows df:', len(df_unique))
print('deleted rows = ', len(df_fillna)-len(df_unique))
# Out:
# original no of rows df: 785741
# no of unique rows df: 508042
# deleted rows =  277699

# %% [markdown]
# ### Data: Management

# %% [markdown]
# * `sample()`

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample()
# Out:
#        job_title_short                                job_title job_location  \
# 118566  Data Scientist  Data Scientist / Biostatistiker (m/w/d)     Anywhere
#
#            job_via job_schedule_type  job_work_from_home search_location  \
# 118566  via Indeed         Full-time                True         Germany
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 118566 2023-05-16 08:26:21                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 118566     Germany        None              NaN              NaN     TCC GmbH
#
#        job_skills         job_type_skills
# 118566      ['r']  {'programming': ['r']}

# %%
df.sample(4)
# Out:
#               job_title_short                                     job_title  \
# 289856          Data Engineer             Junior Software and Data Engineer
# 73995            Data Analyst                          Data Science Analyst
# 644264           Data Analyst  Intermediate Big Data Analyst - AVP (Hybrid)
# 477714  Senior Data Scientist                            Data Platform Lead
#
#               job_location                  job_via        job_schedule_type  \
# 289856          Boston, MA         via ZipRecruiter  Full-time and Part-time
# 73995           Austin, TX          via Recruit.net                Full-time
# 644264     Dublin, Ireland             via LinkedIn                Full-time
# 477714  Seoul, South Korea  via Trabajo.org - 작업 검색                Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 289856               False  Texas, United States 2023-11-28 17:07:37
# 73995                False  Texas, United States 2023-06-01 00:03:51
# 644264               False               Ireland 2023-08-08 12:32:20
# 477714               False           South Korea 2023-01-20 15:29:45
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 289856                  False                  True  United States
# 73995                   False                  True  United States
# 644264                  False                 False        Ireland
# 477714                  False                 False    South Korea
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 289856        None              NaN              NaN
# 73995         None              NaN              NaN
# 644264        None              NaN              NaN
# 477714        None              NaN              NaN
#
#                          company_name  \
# 289856  Commonwealth of Massachusetts
# 73995                       HelioHire
# 644264                           Citi
# 477714                            AIA
#
#                                                job_skills  \
# 289856  ['java', 'python', 'javascript', 'c', 'c#', 'a...
# 73995                          ['python', 'aws', 'linux']
# 644264         ['sql', 'shell', 'python', 'aws', 'spark']
# 477714  ['php', 'java', 'sql', 'python', 'sql server',...
#
#                                           job_type_skills
# 289856  {'cloud': ['aws'], 'other': ['github', 'puppet...
# 73995   {'cloud': ['aws'], 'os': ['linux'], 'programmi...
# 644264  {'cloud': ['aws'], 'libraries': ['spark'], 'pr...
# 477714  {'cloud': ['aws', 'aurora', 'snowflake'], 'dat...

# %%
df.sample(4,random_state=42)
# Out:
#               job_title_short                  job_title  \
# 502901   Senior Data Engineer       Senior Data Engineer
# 406337  Senior Data Scientist  Senior Analytics Engineer
# 659951          Data Engineer              Data Engineer
# 541593           Data Analyst               Data Analyst
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
#
#        salary_rate  salary_year_avg  salary_hour_avg   company_name  \
# 502901        None              NaN              NaN  ManpowerGroup
# 406337        None              NaN              NaN        Harnham
# 659951        None              NaN              NaN    Morgan King
# 541593        None              NaN              NaN        Konnekt
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}

# %% [markdown]
# * `copy()`

# %%
dataset = load_dataset("lukebarousse/data_jobs")
df_original = dataset['train'].to_pandas()

# %%
df_modified = df_original.copy()

# %%
print('Id of df_original :', id(df_original))
print('Id of df_modified :', id(df_modified))
id(df_original)==id(df_modified)
# Out:
# Id of df_original : 3200687042112
# Id of df_modified : 3200423228768
# False

# %%
median = df_modified['salary_year_avg'].median()

df_modified['salary_year_avg'] = df_modified['salary_year_avg'].fillna(median)

df_modified.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# * This concludes whatever the changes we made in df_modified doesn't affect the df_original

# %% [markdown]
# ### Index Management

# %%
import pandas as pd
from datasets import load_dataset

# Loading dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# data cleanup
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'Serial_no'

# %%
df.head(5)
# Out:
#                 job_title_short  \
# Serial_no
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# Serial_no
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# Serial_no
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# 3                       San Antonio, TX   via Diversity.com         Full-time
# 4                        Washington, DC  via Clearance Jobs         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# Serial_no
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# 2                       False               Germany 2023-10-10 13:14:55
# 3                       False  Texas, United States 2023-07-04 13:01:41
# 4                       False                 Sudan 2023-08-07 14:29:36
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# Serial_no
# 0                          False                 False  United States
# 1                          False                 False         Mexico
# 2                          False                 False        Germany
# 3                           True                 False  United States
# 4                          False                 False          Sudan
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# Serial_no
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
#
#                            company_name  \
# Serial_no
# 0                  Boehringer Ingelheim
# 1            Hewlett Packard Enterprise
# 2              ALPHA Augmented Services
# 3          Southwest Research Institute
# 4                       Kristina Daniel
#
#                                                   job_skills  \
# Serial_no
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                              job_type_skills
# Serial_no
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# * #### `reset_index()`

# %%
df_india = df[df['job_country']== "India"]
df_india
# Out:
#                 job_title_short  \
# Serial_no
# 16                Data Engineer
# 19               Data Scientist
# 29               Data Scientist
# 38                 Data Analyst
# 42         Senior Data Engineer
# ...                         ...
# 785712            Data Engineer
# 785715             Data Analyst
# 785716        Software Engineer
# 785718         Business Analyst
# 785740        Software Engineer
#
#                                                    job_title  \
# Serial_no
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# 785712                        India - Collections Analyst II
# 785715     Amul Careers 2023 - Apply Online - Data Analys...
# 785716                           Application Support Analyst
# 785718                         Senior Performance QA Analyst
# 785740                                    AWS System Analyst
#
#                          job_location  \
# Serial_no
# 16           Pune, Maharashtra, India
# 19           Pune, Maharashtra, India
# 29           Pune, Maharashtra, India
# 38                              India
# 42         Chennai, Tamil Nadu, India
# ...                               ...
# 785712                          India
# 785715                          India
# 785716                          India
# 785718                          India
# 785740                          India
#
#                                                      job_via  \
# Serial_no
# 16                                              via LinkedIn
# 19                                                via Indeed
# 29                                                via Exusia
# 38                                           via Trabajo.org
# 42         via HR Software For Growing Businesses | Fresh...
# ...                                                      ...
# 785712                                   melalui BeBee India
# 785715     melalui Jobsleworld - Jobs In India - Job Vaca...
# 785716                                   melalui BeBee India
# 785718                                   melalui BeBee India
# 785740                                        melalui Trigyn
#
#           job_schedule_type  job_work_from_home search_location  \
# Serial_no
# 16                Full-time               False           India
# 19                Full-time               False           India
# 29                Full-time               False           India
# 38                Full-time               False           India
# 42                Full-time               False           India
# ...                     ...                 ...             ...
# 785712      Pekerjaan tetap               False           India
# 785715      Pekerjaan tetap               False           India
# 785716      Pekerjaan tetap               False           India
# 785718      Pekerjaan tetap               False           India
# 785740      Pekerjaan tetap               False           India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# Serial_no
# 16        2023-06-15 13:28:03                  False                 False
# 19        2023-04-26 13:20:12                  False                 False
# 29        2023-03-26 13:16:20                  False                 False
# 38        2023-07-23 13:24:57                  False                 False
# 42        2023-11-10 13:30:41                   True                 False
# ...                       ...                    ...                   ...
# 785712    2023-03-13 06:16:31                  False                 False
# 785715    2023-03-13 06:16:28                  False                 False
# 785716    2023-03-13 06:16:31                  False                 False
# 785718    2023-03-13 06:16:28                  False                 False
# 785740    2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# Serial_no
# 16              India        None              NaN              NaN
# 19              India        None              NaN              NaN
# 29              India        None              NaN              NaN
# 38              India        None              NaN              NaN
# 42              India        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785712          India        None              NaN              NaN
# 785715          India        None              NaN              NaN
# 785716          India        None              NaN              NaN
# 785718          India        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                            company_name  \
# Serial_no
# 16                Hexaware Technologies
# 19                    Bitwise Solutions
# 29                               Exusia
# 38           Jones Lang LaSalle IP, Inc
# 42                                CESIT
# ...                                 ...
# 785712     Varite India Private Limited
# 785715                             Amul
# 785716               CompuGroup Medical
# 785718                  Diebold Nixdorf
# 785740                           Trigyn
#
#                                                   job_skills  \
# Serial_no
# 16         ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19         ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                      None
# 38         ['sql', 'python', 'databricks', 'power bi', 'e...
# 42         ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                      ...
# 785712                                     ['excel', 'flow']
# 785715                                                  None
# 785716                                         ['c#', 'sql']
# 785718                                                  None
# 785740                                       ['aws', 'flow']
#
#                                              job_type_skills
# Serial_no
# 16         {'cloud': ['databricks', 'azure'], 'databases'...
# 19         {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                                      None
# 38         {'analyst_tools': ['power bi', 'excel', 'word'...
# 42         {'async': ['jira'], 'cloud': ['aws'], 'librari...
# ...                                                      ...
# 785712       {'analyst_tools': ['excel'], 'other': ['flow']}
# 785715                                                  None
# 785716                        {'programming': ['c#', 'sql']}
# 785718                                                  None
# 785740                 {'cloud': ['aws'], 'other': ['flow']}
#
# [51088 rows x 17 columns]

# %%
df_india.reset_index(inplace= True)
df_india.head(5)
# Out:
#    Serial_no       job_title_short  \
# 0         16         Data Engineer
# 1         19        Data Scientist
# 2         29        Data Scientist
# 3         38          Data Analyst
# 4         42  Senior Data Engineer
#
#                                      job_title                job_location  \
# 0                            Big Data Engineer    Pune, Maharashtra, India
# 1                               Data Scientist    Pune, Maharashtra, India
# 2                               Data Scientist    Pune, Maharashtra, India
# 3        Data Quality and Governance Analyst 1                       India
# 4  Senior Data Engineer(Python)-1563,1637&1633  Chennai, Tamil Nadu, India
#
#                                              job_via job_schedule_type  \
# 0                                       via LinkedIn         Full-time
# 1                                         via Indeed         Full-time
# 2                                         via Exusia         Full-time
# 3                                    via Trabajo.org         Full-time
# 4  via HR Software For Growing Businesses | Fresh...         Full-time
#
#    job_work_from_home search_location     job_posted_date  \
# 0               False           India 2023-06-15 13:28:03
# 1               False           India 2023-04-26 13:20:12
# 2               False           India 2023-03-26 13:16:20
# 3               False           India 2023-07-23 13:24:57
# 4               False           India 2023-11-10 13:30:41
#
#    job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 0                  False                 False       India        None
# 1                  False                 False       India        None
# 2                  False                 False       India        None
# 3                  False                 False       India        None
# 4                   True                 False       India        None
#
#    salary_year_avg  salary_hour_avg                company_name  \
# 0              NaN              NaN       Hexaware Technologies
# 1              NaN              NaN           Bitwise Solutions
# 2              NaN              NaN                      Exusia
# 3              NaN              NaN  Jones Lang LaSalle IP, Inc
# 4              NaN              NaN                       CESIT
#
#                                           job_skills  \
# 0  ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 1  ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 2                                               None
# 3  ['sql', 'python', 'databricks', 'power bi', 'e...
# 4  ['python', 'sql', 'aws', 'pyspark', 'docker', ...
#
#                                      job_type_skills
# 0  {'cloud': ['databricks', 'azure'], 'databases'...
# 1  {'analyst_tools': ['tableau'], 'libraries': ['...
# 2                                               None
# 3  {'analyst_tools': ['power bi', 'excel', 'word'...
# 4  {'async': ['jira'], 'cloud': ['aws'], 'librari...

# %% [markdown]
# * #### `Set_index()`

# %%
df_india.set_index('Serial_no', inplace=True)
df_india.head(5)
# Out:
#                 job_title_short                                    job_title  \
# Serial_no
# 16                Data Engineer                            Big Data Engineer
# 19               Data Scientist                               Data Scientist
# 29               Data Scientist                               Data Scientist
# 38                 Data Analyst        Data Quality and Governance Analyst 1
# 42         Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                          job_location  \
# Serial_no
# 16           Pune, Maharashtra, India
# 19           Pune, Maharashtra, India
# 29           Pune, Maharashtra, India
# 38                              India
# 42         Chennai, Tamil Nadu, India
#
#                                                      job_via  \
# Serial_no
# 16                                              via LinkedIn
# 19                                                via Indeed
# 29                                                via Exusia
# 38                                           via Trabajo.org
# 42         via HR Software For Growing Businesses | Fresh...
#
#           job_schedule_type  job_work_from_home search_location  \
# Serial_no
# 16                Full-time               False           India
# 19                Full-time               False           India
# 29                Full-time               False           India
# 38                Full-time               False           India
# 42                Full-time               False           India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# Serial_no
# 16        2023-06-15 13:28:03                  False                 False
# 19        2023-04-26 13:20:12                  False                 False
# 29        2023-03-26 13:16:20                  False                 False
# 38        2023-07-23 13:24:57                  False                 False
# 42        2023-11-10 13:30:41                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# Serial_no
# 16              India        None              NaN              NaN
# 19              India        None              NaN              NaN
# 29              India        None              NaN              NaN
# 38              India        None              NaN              NaN
# 42              India        None              NaN              NaN
#
#                          company_name  \
# Serial_no
# 16              Hexaware Technologies
# 19                  Bitwise Solutions
# 29                             Exusia
# 38         Jones Lang LaSalle IP, Inc
# 42                              CESIT
#
#                                                   job_skills  \
# Serial_no
# 16         ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19         ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                      None
# 38         ['sql', 'python', 'databricks', 'power bi', 'e...
# 42         ['python', 'sql', 'aws', 'pyspark', 'docker', ...
#
#                                              job_type_skills
# Serial_no
# 16         {'cloud': ['databricks', 'azure'], 'databases'...
# 19         {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                                      None
# 38         {'analyst_tools': ['power bi', 'excel', 'word'...
# 42         {'async': ['jira'], 'cloud': ['aws'], 'librari...

# %% [markdown]
# * #### `sort_index()`

# %%
df_india.sort_index()
# Out:
#                 job_title_short  \
# Serial_no
# 16                Data Engineer
# 19               Data Scientist
# 29               Data Scientist
# 38                 Data Analyst
# 42         Senior Data Engineer
# ...                         ...
# 785712            Data Engineer
# 785715             Data Analyst
# 785716        Software Engineer
# 785718         Business Analyst
# 785740        Software Engineer
#
#                                                    job_title  \
# Serial_no
# 16                                         Big Data Engineer
# 19                                            Data Scientist
# 29                                            Data Scientist
# 38                     Data Quality and Governance Analyst 1
# 42               Senior Data Engineer(Python)-1563,1637&1633
# ...                                                      ...
# 785712                        India - Collections Analyst II
# 785715     Amul Careers 2023 - Apply Online - Data Analys...
# 785716                           Application Support Analyst
# 785718                         Senior Performance QA Analyst
# 785740                                    AWS System Analyst
#
#                          job_location  \
# Serial_no
# 16           Pune, Maharashtra, India
# 19           Pune, Maharashtra, India
# 29           Pune, Maharashtra, India
# 38                              India
# 42         Chennai, Tamil Nadu, India
# ...                               ...
# 785712                          India
# 785715                          India
# 785716                          India
# 785718                          India
# 785740                          India
#
#                                                      job_via  \
# Serial_no
# 16                                              via LinkedIn
# 19                                                via Indeed
# 29                                                via Exusia
# 38                                           via Trabajo.org
# 42         via HR Software For Growing Businesses | Fresh...
# ...                                                      ...
# 785712                                   melalui BeBee India
# 785715     melalui Jobsleworld - Jobs In India - Job Vaca...
# 785716                                   melalui BeBee India
# 785718                                   melalui BeBee India
# 785740                                        melalui Trigyn
#
#           job_schedule_type  job_work_from_home search_location  \
# Serial_no
# 16                Full-time               False           India
# 19                Full-time               False           India
# 29                Full-time               False           India
# 38                Full-time               False           India
# 42                Full-time               False           India
# ...                     ...                 ...             ...
# 785712      Pekerjaan tetap               False           India
# 785715      Pekerjaan tetap               False           India
# 785716      Pekerjaan tetap               False           India
# 785718      Pekerjaan tetap               False           India
# 785740      Pekerjaan tetap               False           India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# Serial_no
# 16        2023-06-15 13:28:03                  False                 False
# 19        2023-04-26 13:20:12                  False                 False
# 29        2023-03-26 13:16:20                  False                 False
# 38        2023-07-23 13:24:57                  False                 False
# 42        2023-11-10 13:30:41                   True                 False
# ...                       ...                    ...                   ...
# 785712    2023-03-13 06:16:31                  False                 False
# 785715    2023-03-13 06:16:28                  False                 False
# 785716    2023-03-13 06:16:31                  False                 False
# 785718    2023-03-13 06:16:28                  False                 False
# 785740    2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# Serial_no
# 16              India        None              NaN              NaN
# 19              India        None              NaN              NaN
# 29              India        None              NaN              NaN
# 38              India        None              NaN              NaN
# 42              India        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785712          India        None              NaN              NaN
# 785715          India        None              NaN              NaN
# 785716          India        None              NaN              NaN
# 785718          India        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                            company_name  \
# Serial_no
# 16                Hexaware Technologies
# 19                    Bitwise Solutions
# 29                               Exusia
# 38           Jones Lang LaSalle IP, Inc
# 42                                CESIT
# ...                                 ...
# 785712     Varite India Private Limited
# 785715                             Amul
# 785716               CompuGroup Medical
# 785718                  Diebold Nixdorf
# 785740                           Trigyn
#
#                                                   job_skills  \
# Serial_no
# 16         ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19         ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                      None
# 38         ['sql', 'python', 'databricks', 'power bi', 'e...
# 42         ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                      ...
# 785712                                     ['excel', 'flow']
# 785715                                                  None
# 785716                                         ['c#', 'sql']
# 785718                                                  None
# 785740                                       ['aws', 'flow']
#
#                                              job_type_skills
# Serial_no
# 16         {'cloud': ['databricks', 'azure'], 'databases'...
# 19         {'analyst_tools': ['tableau'], 'libraries': ['...
# 29                                                      None
# 38         {'analyst_tools': ['power bi', 'excel', 'word'...
# 42         {'async': ['jira'], 'cloud': ['aws'], 'librari...
# ...                                                      ...
# 785712       {'analyst_tools': ['excel'], 'other': ['flow']}
# 785715                                                  None
# 785716                        {'programming': ['c#', 'sql']}
# 785718                                                  None
# 785740                 {'cloud': ['aws'], 'other': ['flow']}
#
# [51088 rows x 17 columns]

# %%
median_pivot = df_india.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['median','min','max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0         43200.0        142025.0
# Data Analyst                     100500.0         32400.0        650000.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Software Engineer                 79200.0         44418.5        200000.0

# %%
median_pivot.sort_values(by=('min','salary_year_avg'),ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            149653.0         64800.0        170575.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Software Engineer                 79200.0         44418.5        200000.0
# Business Analyst                  64800.0         43200.0        142025.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Data Analyst                     100500.0         32400.0        650000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  64800.0         43200.0        142025.0
# Data Analyst                     100500.0         32400.0        650000.0
# Data Engineer                    147500.0         43200.0        249000.0
# Data Scientist                   114008.0         43200.0        204381.0
# Machine Learning Engineer         79200.0         32500.0        267000.0
# Senior Data Analyst              111175.0         64800.0        177283.0
# Senior Data Engineer             147500.0         35000.0        181765.0
# Senior Data Scientist            149653.0         64800.0        170575.0
# Software Engineer                 79200.0         44418.5        200000.0
